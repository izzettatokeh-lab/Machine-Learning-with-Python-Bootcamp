# %% [markdown]
# <a href="https://colab.research.google.com/github/izzettatokeh-lab/Machine-Learning-with-Python-Bootcamp/blob/main/python_refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables

# %%
# create a labeled storage basket and put a number inside
tomato_price = 150
pepper_price = 80

# pull the value out of the baskets
print(tomato_price)
print(pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# DATA TYPES

# %%
quantity = 50
price = 150.50
item_name = "tomatoes"
stall_is_open =True
print(type(quantity)) #
print(type(price))    #
print(type(item_name)) #
print(type(stall_is_open)) #
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
