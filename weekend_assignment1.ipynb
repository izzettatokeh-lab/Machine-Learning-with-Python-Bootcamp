# %% [markdown]
# <a href="https://colab.research.google.com/github/izzettatokeh-lab/Machine-Learning-with-Python-Bootcamp/blob/main/weekend_assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Izzetta T. Tokeh - 25 May 2026
# Problem 1
Liberia = 1847
print(Liberia)
print("Liberia")
# The first line prints 1847 because it references the variables name without quotes.
# The second line prints "Liberia" because quotation marks tell python to treat it as literal text (a string).
# Out:
# 1847
# Liberia

# %%
# Problem 2
country = "Liberia"
print(country)
print(country, "became independent in", 1847)
# Out:
# Liberia
# Liberia became independent in 1847

# %%
# Problem 3
print('The year is "1847"')
# Out:
# The year is "1847"

# %%
# Problem 4
market_name = "Gobachop Market"   # string
total_mrket_table = 150           # whole number
price_per_bag = 3200.50           #decimal number
is_market_open = True             #true/false

print("Market name:", market_name)
print("Total market tables:", total_mrket_table)
print("Price per bag:", price_per_bag)
print("Is market open:", is_market_open)

print("Type of market_name:", type(market_name))
print("Type of total_market_table:", type(total_market_table))
print("Type of price:", type(price_per_bag))
print("Is market open:", type(is_market_open))
# Out:
# Market name: Gobachop Market
# Total market tables: 150
# Price per bag: 3200.5
# Is market open: True
# Type of market_name: <class 'str'>
# Type of total_market_table: <class 'int'>
# Type of price_per_bag: <class 'float'>
# Is market open: <class 'bool'>

# %%
# Problem 5
current_price = 2550.75
quantity = 10
total_cost= current_price * quantity
print("Total  cost for 10 bags :", total_cost, "LRD")
# Out:
# Total  cost for 10 bags : 25507.5 LRD

# %%
# Problem 6
has_scarcity = False
is_rainy = True

print("Scarcity today:", has_scarcity)
print("Rainy today:", is_rainy)
# Out:
# Scarcity today: False
# Rainy today: True

# %%
# Problem 7
price_per_bag_cassava = 800
quantity_cassava = 25
total_revenue = price_per_bag_cassava * quantity_cassava
print("Total revenue for cassava sales:", total_revenue, "LRD")
# Out:
# Total revenue for cassava sales: 20000 LRD

# %%
# Problem 8
today_price = 3200
increase = 150
tomorrow_price = today_price + increase
print("Tomorrow's rice price:", tomorrow_price, "LRD")
# Out:
# Tomorrow's rice price: 3350 LRD

# %%
# Problem 9
total_onion_cost =1800
numbers_of_traders = 3
cost_per_trader = total_onion_cost / numbers_of_traders
print("Cost per trader for the shared bag of onions:", cost_per_trader, "LRD")
# Out:
# Cost per trader for the shared bag of onions: 600.0 LRD

# %%
# Problem 10
original_price = 2500
discount_rate = 0.10  # 10% written as a decimal
discount_amount = original_price * discount_rate
final_price = original_price - discount_amount
print("Discount amount subtracted:", discount_amount, "LRD")
print("Final price for palm oil after discount:", final_price, "LRD")
# Out:
# Discount amount subtracted: 250.0 LRD
# Final price for palm oil after discount: 2250.0 LRD

# %%
# Problem 11
item = "cassava"
price = 800

print(item)     # Prints the value: cassava
print("item")   # Prints th word: item
print(price)    # prints the value: 800
print("price")  # Prints the word: price

# Without quotes, python reads the data stored in the vaiable.
# With quotes, python just prints the letters inside the quotes directly.
# Out:
# cassava
# item
# 800
# price

# %%
# Problem 12
product = "pepper"
cost = 150.50
print("One bag of", product, "costs", cost, "LRD")
# Out:
# One bag of pepper costs 150.5 LRD

# %%
# Bonus Problem
Liberia = 1847
print("Liberis became independent in", Liberia)
print('"Liberia is', Liberia, 'years old?"')
# Out:
# Liberis became independent in 1847
# "Liberia is 1847 years old?"

# %% [markdown]
# Homework Assignment 2

# %%
# Question 1_A_B

transport_cost = "750"
total_delivery_cost = int(transport_cost) + 250
print(f"Ma Christiana, your final shipping cost is: {total_delivery_cost} LRD.")
# Out:
# Ma Christiana, your final shipping cost is: 1000 LRD.

# %%
# Question 2_A_B
# A flat list like [45, 12, 88]is 1D.
# Machine Learning models expect input X as a 2D matrix/table with rows and columns, like a spreadsheet.
# Tink of it like a dlivery truck: it needs items packed in a crate with defined rows ans columns, not loose on the truck bed.
# The model needs the shape (n_samples, n_features).

# B
loose_stock = [45, 12, 88]
shipping_crate = [[45, 12, 8]]   #double brackets make it 2D with row, 3 columns
print(shipping_crate)
print(loose_stock)
# Out:
# [[45, 12, 8]]
# [45, 12, 88]

# %%
# Question 3_A_B

yield_model_configs = {
    "engine_type": "Decision Tree",
    "max_depth_layers": 15,
    "strict_mode": True
}
print(yield_model_configs["engine_type"])
print(yield_model_configs["max_depth_layers"])
print(yield_model_configs["strict_mode"])

# F-string
print(f"System check: Turning engine depth to {yield_model_configs['max_depth_layers']}")
# Out:
# Decision Tree
# 15
# True
# System check: Turning engine depth to 15

# %%
# Question 4A_B
# gobachop_data.shape vs
# gobachop_data_.shape() Use
# gobachop_data.shape without()

 # Explanation using Delivery Truck Analogy:

 # An attribute like .shape is a description of the truck-it tells you how many rows and columns exist right now. You just read it.
 # A method like .shape() would be an action the truck performs.
 # Since .shape is an attribute, adding() causes an error: TyprError: 'tuple'
 # object is not collable.

 # B. Command to get top row

import pandas as pd

gobachop_data = pd.DataFrame({
    "Vendor": ["Ma Musu", "Sia", "Kumba"],
    "Sales": [4000, 9500, 1500],
 })
print(gobachop_data.shape)
print(gobachop_data.head(1))
print(gobachop_data.head(3))
print(gobachop_data.tail())
# Out:
# (3, 2)
#     Vendor  Sales
# 0  Ma Musu   4000
#     Vendor  Sales
# 0  Ma Musu   4000
# 1      Sia   9500
# 2    Kumba   1500
#     Vendor  Sales
# 0  Ma Musu   4000
# 1      Sia   9500
# 2    Kumba   1500
